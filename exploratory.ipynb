# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
uber15 = pd.read_csv('uber_trips_2015.csv.gz', compression='gzip', header=0, sep=',')

# %%
list(uber15.columns)
# Out:
# ['pickup_datetime', 'pickup_location_id', 'dispatch_base', 'affiliate_base']

# %%
uber15.describe()
# Out:
#        pickup_location_id
# count        1.427048e+07
# mean         1.520574e+02
# std          7.159620e+01
# min          1.000000e+00
# 25%          9.200000e+01
# 50%          1.570000e+02
# 75%          2.300000e+02
# max          2.650000e+02

# %%
uber15['pickup_datetime'] =  pd.to_datetime(uber15['pickup_datetime'])

# %%
type(uber15['pickup_datetime'][0])
# Out:
# pandas.tslib.Timestamp

# %%
uber15['pickup_datetime'].describe()
# Out:
# count                14270479
# unique                2744783
# top       2015-06-27 20:52:00
# freq                      213
# first     2015-01-01 00:00:05
# last      2015-06-30 23:59:00
# Name: pickup_datetime, dtype: object

# %%
timeseries = uber15.set_index('pickup_datetime')

# %%
timeseries.describe()
# Out:
#        pickup_location_id
# count        1.427048e+07
# mean         1.520574e+02
# std          7.159620e+01
# min          1.000000e+00
# 25%          9.200000e+01
# 50%          1.570000e+02
# 75%          2.300000e+02
# max          2.650000e+02

# %%
list(timeseries.columns)
# Out:
# ['pickup_location_id', 'dispatch_base', 'affiliate_base']

# %%
timeseries.date = timeseries.resample('D')

# %%
timeseries.date.count()
# Out:
#                  pickup_location_id  dispatch_base  affiliate_base
# pickup_datetime
# 2015-01-01                    58045          58045           55383
# 2015-01-02                    40287          40287           38469
# 2015-01-03                    59844          59844           57383
# 2015-01-04                    41943          41943           39998
# 2015-01-05                    43678          43678           41858
# 2015-01-06                    53539          53539           51407
# 2015-01-07                    63375          63375           60905
# 2015-01-08                    73016          73016           70034
# 2015-01-09                    72124          72124           69035
# 2015-01-10                    80656          80656           77031
# 2015-01-11                    58751          58751           56011
# 2015-01-12                    58991          58991           56674
# 2015-01-13                    64765          64765           62227
# ...

# %%
df = timeseries.date.count()

# %%
df.to_csv('uber15-timeseries-resampled-D-count', sep=',', encoding='utf-8')

# %%
uber14 = pd.read_csv('uber_trips_2014.csv.gz', compression='gzip', header=0, sep=',')

# %%
uber14['pickup_datetime'] = pd.to_datetime(uber14['pickup_datetime'], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/tslib.pyx in pandas.tslib.array_to_datetime (pandas/tslib.c:44368)()
#
# pandas/src/datetime.pxd in datetime._string_to_dts (pandas/tslib.c:95676)()
#
# ValueError: Error parsing datetime string "9/18/2014 8:26:00" at position 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /Users/nilbot/anaconda3/lib/python3.6/site-packages/dateutil/parser.py in token_could_be_year(token, year)
#     382         try:
# --> 383             return int(token) == year
#     384         except ValueError:
#
# ValueError: invalid literal for int() with base 10: ' '
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ...
